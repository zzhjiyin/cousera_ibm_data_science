# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * Introduction & Business Problem
# * Data
# * Analysis
# * Results and Discussion
# * Conclusion

# %% [markdown]
# ### Introduction & Business Problem

# %% [markdown]
# #### Introduction
# Hong Kong is one of the most densely populated places in the world, with an overall density of some 6,300 people per square kilometre.. The territory has become one of the world's most significant financial centres and commercial ports.Ethnically, Hong Kong mainly consists of Han Chinese who constitute approximately 92% of the population. Of these, many originate from various regions in Canton. There are also a number of descendants of immigrants from elsewhere in Southern China and around the world after the end of World War II.
# #### Business Problem
# In this project we will try to find an optimal location for a restaurant.Specifically, this report will be targeted to stakeholders interested in opening an **Cantonese restaurant in Hong Kong**.
# Although there are so many restaurants in Hong Kong. We found there are few restaurant crowed particularly the Cantonese restaurant. We are supposed to find a **location where is close to the city center as possible**, Also there are **no similar restaurant nearby or the restaurant with bad reputation**.

# %% [markdown]
# ### Data

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * number of and distance to Cantonese restaurants in the neighborhood, if any
# * distance of neighborhood from city center

# %% [markdown]
# Following data sources will be needed to extract/generate the required information:
# * number of restaurants and their type and location in every neighborhood will be obtained using Foursquare API
# * coordinate of Hong Kong center will be obtained using *geopy.geocoders* of well known Hong Kong location (Central)

# %% [markdown]
# #### Neighborhood Candidates

# %% [markdown]
# As the beginning,we have to find the location of the city center. We will use FourSquare API to extract the data what we need surrounded by the Central.
# First we get the latitude & longitude of Central.

# %% [markdown]
# #### Import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.3.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Let's again assume that you are staying at HongKong.

# %%
address = 'Central,Hong Kong'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 22.2850394 114.1583819

# %% [markdown]
# #### Search for a specific venue category
# 1. Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = '5ESZXISFGD2ZO5NQC0DUKHXTYIT4PQT0U01WQYLD1PLEITLW' # your Foursquare ID
CLIENT_SECRET = 'EJFLXNIT4T52K22ZWDJBV0CSMMZCFC2VHKC2XWXAWZXUJAKN' # your Foursquare Secret
VERSION = '20200210'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5ESZXISFGD2ZO5NQC0DUKHXTYIT4PQT0U01WQYLD1PLEITLW
# CLIENT_SECRET:EJFLXNIT4T52K22ZWDJBV0CSMMZCFC2VHKC2XWXAWZXUJAKN

# %% [markdown]
# 2.Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
search_query = 'Food'
LIMIT = 100
radius = 1000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f5941735', 'name': 'G...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...    False
# 3  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...    False
# 4  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...    False
#
#                          id                  location.address location.cc  \
# 0  537dedb3498e9239c5267673        Kinwick Centre, Shelley St          HK
# 1  4ccfa2326449a09306f9c5cf                    Man Cheung St.          HK
# 2  4bc541bf5935c9b6bcc9a5d2  B/F, Pacific Place, 88 Queensway          HK
# 3  533fff61498e424c5874d29e         Shop 206, Shun Tak Centre          HK
# 4  4f56e921e4b01d8a92a28b70                  92 Wellington St          HK
#
#   location.city location.country                location.crossStreet  \
# 0            中区               香港                                 NaN
# 1            中環               香港  Hong Kong Station, Airport Express
# 2            中環               香港                                 NaN
# 3    Sheung Wan               香港                                 NaN
# 4            中環               香港        btwn Cochrain & Pottinger St
#
#    location.distance                          location.formattedAddress  \
# 0                623                   [Kinwick Centre, Shelley St, 香港]
# 1                  0  [Man Cheung St. (Hong Kong Station, Airport Ex...
# 2               1026        [B/F, Pacific Place, 88 Queensway, 中西區, 香港]
# 3                633         [Shop 206, Shun Tak Centre, Hong Kong, 香港]
# 4                450  [92 Wellington St (btwn Cochrain & Pottinger S...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 22.28200948348554...     22.282009
# 1  [{'label': 'display', 'lat': 22.28504661513501...     22.285047
# 2  [{'label': 'display', 'lat': 22.27792296623498...     22.277923
# 3  [{'label': 'display', 'lat': 22.28779568111136...     22.287796
# 4  [{'label': 'display', 'lat': 22.28292072899061...     22.282921
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    114.153296                   NaN                 NaN            NaN
# 1    114.158380                   NaN                 NaN            中西區
# 2    114.164712                   NaN                 NaN            中西區
# 3    114.152997                   NaN                 NaN      Hong Kong
# 4    114.154651                   NaN                 NaN            中西區
#
#                      name    referralId venuePage.id
# 0    Marks & Spencer Food  v-1581429216          NaN
# 1  Food Expression (現代煮意)  v-1581429216          NaN
# 2         Great Food Hall  v-1581429216          NaN
# 3    Marks & Spencer Food  v-1581429216          NaN
# 4    Mana! Fast Slow Food  v-1581429216     67771409

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                          name                     categories  \
# 0                        Marks & Spencer Food                   Gourmet Shop
# 1                      Food Expression (現代煮意)                     Restaurant
# 2                             Great Food Hall                    Supermarket
# 3                        Marks & Spencer Food                    Supermarket
# 4                        Mana! Fast Slow Food  Vegetarian / Vegan Restaurant
# 5                  Chiu Lung Fast Food (昭隆美食)             Chinese Restaurant
# 6                                   nood food                      Juice Bar
# 7                                   Soul Food                Thai Restaurant
# 8                   Sun Hing Fast Food (新興美食)               Asian Restaurant
# 9              Observation Wheel Food & Drink                       Creperie
# 10                     Vietnam Fast Food (越僑)          Vietnamese Restaurant
# 11     Sheung Wan Cooked Food Centre (上環熟食中心)                     Food Court
# 12                   Master Food Company 匯業餐廳             Chinese Restaurant
# 13               Good Luck Thai Food (鴻運泰國美食)                Thai Restaurant
# 14  Queen Street Cooked Food Market (皇后街熟食市場)                     Food Court
# 15                       Marks & Spencer Food                  Grocery Store
# 16            Greenixs Korea Food Court (綠味亭)              Korean Restaurant
# 17                  Delicious Food Shop 東方小食店                    Snack Place
# 18                   Yuk Kin Fast Food (郁健快餐)           Hong Kong Restaurant
# 19                                  Nood Food                      Juice Bar
# 20                                  nood food                      Juice Bar
# 21                               Food Le Parc                  Grocery Store
# 22                                  Nood Food                      Juice Bar
# 23                            Just About Food                          Diner
# 24                                  Nood Food                      Juice Bar
# 25                 Ponti Food and Wine Cellar                      Wine Shop
# 26                                  nood food                      Juice Bar
# 27       Orchid Thai Food Restaurant & Lounge                            Bar
# 28           Kai Bo Food Supermarket 佳寶食品超級市場                         Market
# 29                       Marks & Spencer Food                  Grocery Store
# 30              Papa Gomes’ Quick Indian Food              Indian Restaurant
# 31                       Marks & Spencer Food                  Grocery Store
# 32                                  Asia Food                    Supermarket
# 33  Food and Environmental Hygiene Department            Government Building
# 34                           Today's Food Lab                           Café
# 35                                Fresco Food                  Hot Dog Joint
# 36                         Le Souk halal food            Moroccan Restaurant
# 37                                  nood food                      Juice Bar
# 38                                  Thai Food                Thai Restaurant
# 39                                  nood food                 Breakfast Spot
# 40                     Sun Connie's Fast Food           Fast Food Restaurant
# 41               Hing Lung Food Place Limited                        Butcher
# 42                            FOODBOX Central                     Restaurant
# 43      Finewood Fast Food Restaurant 快活美食茶餐廳           Fast Food Restaurant
# 44                   Natural Food & Beverages                   Liquor Store
# 45                     Marks & Spencer (馬莎百貨)               Department Store
# 46              Glorious Fast Food Restaurant             Chinese Restaurant
# 47                  Wing Yue Marine Food 永裕海味                   Gourmet Shop
# 48           Restaurant Shiki·Etsu (四季·悅日本料理)            Japanese Restaurant
# 49                             Oddies Foodies                 Ice Cream Shop
#
#                                               address  cc                city  \
# 0                          Kinwick Centre, Shelley St  HK                  中区
# 1                                      Man Cheung St.  HK                  中環
# 2                    B/F, Pacific Place, 88 Queensway  HK                  中環
# 3                           Shop 206, Shun Tak Centre  HK          Sheung Wan
# 4                                    92 Wellington St  HK                  中環
# 5                                  21-23 Chiu Lung St  HK                  中環
# 6   2/F Asia Standard Tower,  59-65 Queen's Road C...  HK                  中環
# 7                                     28 Elgin Street  HK                  香港
# 8                                         中環昭隆街9號B舖地下  HK                 NaN
# 9                                                 NaN  HK                 NaN
# 10                                     12 Tit Hong Ln  HK                  中環
# 11  Sheung Wan Municipal Services Bldg, 345 Queen'...  HK          Sheung Wan
# 12                                  97A Wellington St  HK                  中環
# 13                                G/F, 13 Wing Wah Ln  HK                  香港
# 14                             1/F, 38 Des Voeux Rd W  HK          Sheung Wan
# 15                              MTR Admiralty Station  HK                  金鐘
# 16                           G/F & CL/F, 5 Jervois St  HK          Sheung Wan
# 17                                   21-23 Caine Road  HK                 NaN
# 18                                 6 Tai Ping Shan St  HK          Sheung Wan
# 19                                    32 Hollywood Rd  HK                  香港
# 20                                        IFC Level 3  HK                  香港
# 21                              2 Queens Road Central  HK                  香港
# 22     18/F, California Tower, 30-32 D'Arguila Street  HK                 NaN
# 23        Shop HOK 55, MTR Hong Kong Station, Central  HK                 NaN
# 24                       L1, Pacific Place, Queensway  HK                  香港
# 25                                                NaN  HK                 NaN
# 26                            Level 2, Fairmont House  HK                  中環
# 27                               98 Wellington Street  HK                  香港
# 28                                  Wellington Street  HK                 NaN
# 29                          MTR Central Station kiosk  HK                 NaN
# 30                 G/F, Ryan Mansion, 31-37 Mosque St  HK          Mid-Levels
# 31                        Shop 07-08, Queensway Plaza  HK                  金鐘
# 32                                        Gage Street  HK                 NaN
# 33  10th Floor Sheung Wan Municipal Services Build...  HK                 NaN
# 34                                    6 Bonham Strand  HK          Sheung Wan
# 35                                 34 Wing Lok Street  HK          Sheung Wan
# 36               4 Staunton Street, Central & Western  HK                 NaN
# 37                           Level 3 Hutchinson House  HK                  中環
# 38                                   17-19 Hillier St  HK          Sheung Wan
# 39                                      3 Garden Road  HK  3/f champion tower
# 40                                                NaN  HK                 NaN
# 41                                                NaN  HK                 NaN
# 42             HOK 68, Level 1, Hong Kong MTR Station  HK                  中環
# 43                                     102 Jervois St  HK          Sheung Wan
# 44                                                NaN  HK                 NaN
# 45         B/F-1/F, Central Tower, 22-28 Queen's Rd C  HK                  中環
# 46                                       147 Caine Rd  HK                 NaN
# 47                               32-36 Des Voeux Rd W  HK          Sheung Wan
# 48  Shop A1, UG/F, Far East Finance Centre, 16 Har...  HK                  中環
# 49                                        45 Gough St  HK                  香港
#
#    country                         crossStreet  distance  \
# 0       香港                                 NaN       623
# 1       香港  Hong Kong Station, Airport Express         0
# 2       香港                                 NaN      1026
# 3       香港                                 NaN       633
# 4       香港        btwn Cochrain & Pottinger St       450
# 5       香港                                 NaN       313
# 6       香港          59-65 Queen's Road Central       363
# 7       香港                                 NaN       713
# 8       香港                                 NaN       328
# 9       香港                                 NaN       359
# 10      香港                                 NaN       346
# 11      香港                                 NaN       896
# 12      香港                                 NaN       468
# 13      香港                                 NaN       535
# 14      香港                                 NaN      1162
# 15      香港                                 NaN      1004
# 16      香港                                 NaN       586
# 17      香港                                 NaN       722
# 18      香港                                 NaN       998
# 19      香港                                 NaN       625
# 20      香港                                 NaN        80
# 21      香港                                 NaN       596
# 22      香港                                 NaN       575
# 23      香港                                 NaN       206
# 24      香港                                 NaN      1009
# 25      香港                                 NaN       462
# 26      香港                                 NaN       719
# 27      香港                                 NaN       470
# 28      香港                                 NaN       486
# 29      香港                                 NaN       464
# 30      香港                                 NaN       904
# 31      香港                                 NaN       786
# 32      香港                                 NaN       570
# 33      香港                                 NaN       879
# 34      香港                                 NaN       598
# 35      香港                                 NaN       717
# 36      香港                                 NaN       672
# 37      香港                                 NaN       619
# 38      香港                                 NaN       698
# 39      香港                                 NaN       772
# 40      香港                                 NaN       693
# 41      香港                                 NaN       769
# 42      香港                                 NaN        65
# 43      香港                                 NaN       773
# 44      香港                                 NaN       899
# 45      香港                                 NaN       426
# 46      香港                                 NaN      1009
# 47      香港                                 NaN      1200
# 48      香港                                 NaN       841
# 49      香港                                 NaN       664
#
#                                      formattedAddress  \
# 0                    [Kinwick Centre, Shelley St, 香港]
# 1   [Man Cheung St. (Hong Kong Station, Airport Ex...
# 2         [B/F, Pacific Place, 88 Queensway, 中西區, 香港]
# 3          [Shop 206, Shun Tak Centre, Hong Kong, 香港]
# 4   [92 Wellington St (btwn Cochrain & Pottinger S...
# 5                       [21-23 Chiu Lung St, 中西區, 香港]
# 6   [2/F Asia Standard Tower,  59-65 Queen's Road ...
# 7                               [28 Elgin Street, 香港]
# 8                                   [中環昭隆街9號B舖地下, 香港]
# 9                                                [香港]
# 10                          [12 Tit Hong Ln, 中西區, 香港]
# 11  [Sheung Wan Municipal Services Bldg, 345 Queen...
# 12                       [97A Wellington St, 中西區, 香港]
# 13                          [G/F, 13 Wing Wah Ln, 香港]
# 14            [1/F, 38 Des Voeux Rd W, Hong Kong, 香港]
# 15                   [MTR Admiralty Station, 中西區, 香港]
# 16                     [G/F & CL/F, 5 Jervois St, 香港]
# 17                             [21-23 Caine Road, 香港]
# 18                           [6 Tai Ping Shan St, 香港]
# 19                              [32 Hollywood Rd, 香港]
# 20                                  [IFC Level 3, 香港]
# 21                        [2 Queens Road Central, 香港]
# 22  [18/F, California Tower, 30-32 D'Arguila Stree...
# 23  [Shop HOK 55, MTR Hong Kong Station, Central, 香港]
# 24                 [L1, Pacific Place, Queensway, 香港]
# 25                                               [香港]
# 26                 [Level 2, Fairmont House, 中西區, 香港]
# 27                         [98 Wellington Street, 香港]
# 28                            [Wellington Street, 香港]
# 29                    [MTR Central Station kiosk, 香港]
# 30           [G/F, Ryan Mansion, 31-37 Mosque St, 香港]
# 31             [Shop 07-08, Queensway Plaza, 中西區, 香港]
# 32                                  [Gage Street, 香港]
# 33  [10th Floor Sheung Wan Municipal Services Buil...
# 34                   [6 Bonham Strand, Hong Kong, 香港]
# 35                           [34 Wing Lok Street, 香港]
# 36         [4 Staunton Street, Central & Western, 香港]
# 37                [Level 3 Hutchinson House, 中西區, 香港]
# 38                             [17-19 Hillier St, 香港]
# 39                     [3 Garden Road, Hong Kong, 香港]
# 40                                               [香港]
# 41                                               [香港]
# 42  [HOK 68, Level 1, Hong Kong MTR Station, 中西區, 香港]
# 43                               [102 Jervois St, 香港]
# 44                                               [香港]
# 45  [B/F-1/F, Central Tower, 22-28 Queen's Rd C, 中...
# 46                                 [147 Caine Rd, 香港]
# 47              [32-36 Des Voeux Rd W, Hong Kong, 香港]
# 48  [Shop A1, UG/F, Far East Finance Centre, 16 Ha...
# 49                                  [45 Gough St, 香港]
#
#                                        labeledLatLngs        lat         lng  \
# 0   [{'label': 'display', 'lat': 22.28200948348554...  22.282009  114.153296
# 1   [{'label': 'display', 'lat': 22.28504661513501...  22.285047  114.158380
# 2   [{'label': 'display', 'lat': 22.27792296623498...  22.277923  114.164712
# 3   [{'label': 'display', 'lat': 22.28779568111136...  22.287796  114.152997
# 4   [{'label': 'display', 'lat': 22.28292072899061...  22.282921  114.154651
# 5   [{'label': 'display', 'lat': 22.28265943293749...  22.282659  114.156753
# 6   [{'label': 'display', 'lat': 22.28308755592456...  22.283088  114.155551
# 7   [{'label': 'display', 'lat': 22.28166764962636...  22.281668  114.152495
# 8   [{'label': 'display', 'lat': 22.28252120232423...  22.282521  114.156717
# 9   [{'label': 'display', 'lat': 22.285526, 'lng':...  22.285526  114.161833
# 10  [{'label': 'display', 'lat': 22.28449487824889...  22.284495  114.155072
# 11  [{'label': 'display', 'lat': 22.28593617283536...  22.285936  114.149729
# 12  [{'label': 'display', 'lat': 22.28372320007555...  22.283723  114.154065
# 13  [{'label': 'display', 'lat': 22.28116524338975...  22.281165  114.155296
# 14  [{'label': 'display', 'lat': 22.28722789768086...  22.287228  114.147346
# 15  [{'label': 'display', 'lat': 22.27820261118634...  22.278203  114.164740
# 16  [{'label': 'display', 'lat': 22.28523059359497...  22.285231  114.152688
# 17  [{'label': 'display', 'lat': 22.27982410833889...  22.279824  114.154215
# 18  [{'label': 'display', 'lat': 22.28442669319045...  22.284427  114.148711
# 19  [{'label': 'display', 'lat': 22.28198267242313...  22.281983  114.153286
# 20  [{'label': 'display', 'lat': 22.284978, 'lng':...  22.284978  114.159157
# 21  [{'label': 'display', 'lat': 22.27993763583862...  22.279938  114.160165
# 22  [{'label': 'display', 'lat': 22.280751, 'lng':...  22.280751  114.155257
# 23  [{'label': 'display', 'lat': 22.28349227460503...  22.283492  114.159492
# 24  [{'label': 'display', 'lat': 22.27808752449198...  22.278088  114.164670
# 25  [{'label': 'display', 'lat': 22.28099932888706...  22.280999  114.159417
# 26  [{'label': 'display', 'lat': 22.27996309825888...  22.279963  114.162712
# 27  [{'label': 'display', 'lat': 22.283289, 'lng':...  22.283289  114.154229
# 28  [{'label': 'display', 'lat': 22.28352812579579...  22.283528  114.153953
# 29  [{'label': 'display', 'lat': 22.28105312802578...  22.281053  114.159719
# 30  [{'label': 'display', 'lat': 22.279866, 'lng':...  22.279866  114.151609
# 31  [{'label': 'display', 'lat': 22.27985293036736...  22.279853  114.163564
# 32  [{'label': 'display', 'lat': 22.283807, 'lng':...  22.283807  114.153009
# 33  [{'label': 'display', 'lat': 22.285975, 'lng':...  22.285975  114.149901
# 34  [{'label': 'display', 'lat': 22.285315, 'lng':...  22.285315  114.152576
# 35  [{'label': 'display', 'lat': 22.28596790262612...  22.285968  114.151492
# 36  [{'label': 'display', 'lat': 22.28183200287249...  22.281832  114.152852
# 37  [{'label': 'display', 'lat': 22.2809955904826,...  22.280996  114.162519
# 38  [{'label': 'display', 'lat': 22.28536125221662...  22.285361  114.151605
# 39  [{'label': 'display', 'lat': 22.278528, 'lng':...  22.278528  114.160980
# 40  [{'label': 'display', 'lat': 22.284894, 'lng':...  22.284894  114.151654
# 41  [{'label': 'display', 'lat': 22.28590011596679...  22.285900  114.150970
# 42  [{'label': 'display', 'lat': 22.284725, 'lng':...  22.284725  114.157844
# 43  [{'label': 'display', 'lat': 22.285414, 'lng':...  22.285414  114.150884
# 44  [{'label': 'display', 'lat': 22.286475, 'lng':...  22.286475  114.149786
# 45  [{'label': 'display', 'lat': 22.28143972978153...  22.281440  114.156964
# 46  [{'label': 'display', 'lat': 22.283115, 'lng':...  22.283115  114.148800
# 47  [{'label': 'display', 'lat': 22.28786945342953...  22.287869  114.147134
# 48  [{'label': 'display', 'lat': 22.28010603395644...  22.280106  114.164567
# 49  [{'label': 'display', 'lat': 22.28429076650261...  22.284291  114.151980
#
#    neighborhood postalCode      state                        id
# 0           NaN        NaN        NaN  537dedb3498e9239c5267673
# 1           NaN        NaN        中西區  4ccfa2326449a09306f9c5cf
# 2           NaN        NaN        中西區  4bc541bf5935c9b6bcc9a5d2
# 3           NaN        NaN  Hong Kong  533fff61498e424c5874d29e
# 4           NaN        NaN        中西區  4f56e921e4b01d8a92a28b70
# 5       Central        NaN        中西區  4ca6a13cb0b8236a4b96a1e6
# 6           NaN        NaN        中西區  522b194711d2d5f6266289c5
# 7           NaN        NaN        NaN  5791f50f38fab55334b8cb05
# 8           NaN        NaN        NaN  4d58ca847e2237040d59a973
# 9           NaN        NaN        NaN  5683d3a2498ec2f0d370de68
# 10          NaN        NaN        中西區  4bd1a63977b29c74feea8c82
# 11          NaN        NaN        NaN  4eb3d7d877c897273652ca19
# 12          NaN        NaN        中西區  4e7c1ea3b8f75b2042a7c7e3
# 13          NaN        NaN        NaN  4b0588d6f964a5207adc22e3
# 14   Sheung Wan        NaN  Hong Kong  4c0252d2187ec928080ab47b
# 15          NaN        NaN        中西區  55a1e359498ec0b05c5079f7
# 16          NaN        NaN        NaN  533a41d0498ef2793daea5ed
# 17          NaN        NaN        NaN  50e62a28e4b0c751057dc48f
# 18          NaN        NaN        NaN  4d31497d5c2db60cb1d6b66c
# 19          NaN        NaN        NaN  53b28152498e8e174cabc934
# 20          NaN        NaN        NaN  5ab4c8891987ec33c08ba3c2
# 21          NaN        NaN        NaN  5afa5a42dec1d6002c7e8e3a
# 22          NaN        NaN        NaN  560cb17f498ebf43db58949a
# 23          NaN        NaN        NaN  5537190d498e875071e65944
# 24          NaN        NaN        NaN  59ae5b553b4e005ece9a2351
# 25          NaN        NaN        NaN  4c09e137009a0f47fe9ee8bf
# 26          NaN        NaN        中西區  53dedb64498eb78b8c5f265f
# 27          NaN        NaN        NaN  4b0588cdf964a520b4da22e3
# 28          NaN        NaN        NaN  5129df90e4b0fd966410da3b
# 29          NaN        NaN        NaN  55669c49498e2f10228b956a
# 30          NaN        NaN        NaN  5ddf55eabc7298000818d7b5
# 31          NaN        NaN        中西區  5729e864498e72712a9d2eac
# 32          NaN        NaN        NaN  57cbd43f498e011eae709593
# 33          NaN        NaN        NaN  51e4a0b4498ee389337de289
# 34          NaN        NaN  Hong Kong  5a72b03f8ad62e6caa9f206f
# 35          NaN        NaN        NaN  4da41ac37ccc816ef9148a7b
# 36          NaN        NaN        NaN  523fda407e48d4032b5111b6
# 37          NaN        NaN        中西區  56c5473bcd10b75bb9929555
# 38          NaN        NaN        NaN  4cc9700441e75481f94e5c84
# 39          NaN        NaN  Hong Kong  57f1a97acd1070010da7b16e
# 40          NaN        NaN        NaN  4ed7153c2c5b95fea165eadc
# 41          NaN        NaN        NaN  536db3dc498efd959a3bf9aa
# 42          NaN        NaN        中西區  5976d56d002f4c4336fed1ba
# 43          NaN        NaN        NaN  4b135595f964a5206f9623e3
# 44          NaN        NaN        NaN  580039bbd67cc1f3e8d58031
# 45          NaN        NaN        中西區  4b0588ddf964a520a4dd22e3
# 46          NaN        NaN        NaN  4cce6b2cba79a1cdabe946cb
# 47          NaN        NaN  Hong Kong  4daa8d8a6e81162ae7d9f395
# 48          NaN        NaN        中西區  4be25953b02ec9b676de4cc0
# 49          NaN    Central        NaN  5651315238fa31e5c972787b

# %% [markdown]
# #### visualize the results

# %%
dataframe_filtered.name
# Out:
# 0                          Marks & Spencer Food
# 1                        Food Expression (現代煮意)
# 2                               Great Food Hall
# 3                          Marks & Spencer Food
# 4                    Chiu Lung Fast Food (昭隆美食)
# 5                          Mana! Fast Slow Food
# 6                                     nood food
# 7                     Sun Hing Fast Food (新興美食)
# 8                        Vietnam Fast Food (越僑)
# 9                Observation Wheel Food & Drink
# 10       Sheung Wan Cooked Food Centre (上環熟食中心)
# 11                                    Soul Food
# 12                     Master Food Company 匯業餐廳
# 13    Queen Street Cooked Food Market (皇后街熟食市場)
# 14                 Good Luck Thai Food (鴻運泰國美食)
# 15              Greenixs Korea Food Court (綠味亭)
# 16                         Marks & Spencer Food
# 17                     Yuk Kin Fast Food (郁健快餐)
# 18                    Delicious Food Shop 東方小食店
# 19                                    Nood Food
# 20                                    nood food
# 21                                 Food Le Parc
# 22                              Just About Food
# 23                                    Nood Food
# 24                                    Nood Food
# 25                         Marks & Spencer Food
# 26                   Ponti Food and Wine Cellar
# 27                                    nood food
# 28                                    nood food
# 29         Orchid Thai Food Restaurant & Lounge
# 30                         Marks & Spencer Food
# 31             Kai Bo Food Supermarket 佳寶食品超級市場
# 32                Papa Gomes’ Quick Indian Food
# 33        Finewood Fast Food Restaurant 快活美食茶餐廳
# 34                                    Thai Food
# 35    Food and Environmental Hygiene Department
# 36                                    Asia Food
# 37                             Today's Food Lab
# 38                                  Fresco Food
# 39                       Sun Connie's Fast Food
# 40                              FOODBOX Central
# 41                           Le Souk halal food
# 42                 Hing Lung Food Place Limited
# 43                                    nood food
# 44                       Marks & Spencer (馬莎百貨)
# 45                     Natural Food & Beverages
# 46                Glorious Fast Food Restaurant
# 47                    Wing Yue Marine Food 永裕海味
# 48             Restaurant Shiki·Etsu (四季·悅日本料理)
# 49                                      Foodbox
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Central
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# convert to *pd.DataFrame* and filter the columns specifically

# %%
dataframe.shape
# Out:
# (50, 19)

# %%
hk_df = pd.DataFrame(dataframe_filtered)
hk_df.head()
# Out:
#                      name                     categories  \
# 0    Marks & Spencer Food                   Gourmet Shop
# 1  Food Expression (現代煮意)                     Restaurant
# 2         Great Food Hall                    Supermarket
# 3    Marks & Spencer Food                    Supermarket
# 4    Mana! Fast Slow Food  Vegetarian / Vegan Restaurant
#
#                             address  cc        city country  \
# 0        Kinwick Centre, Shelley St  HK          中区      香港
# 1                    Man Cheung St.  HK          中環      香港
# 2  B/F, Pacific Place, 88 Queensway  HK          中環      香港
# 3         Shop 206, Shun Tak Centre  HK  Sheung Wan      香港
# 4                  92 Wellington St  HK          中環      香港
#
#                           crossStreet  distance  \
# 0                                 NaN       623
# 1  Hong Kong Station, Airport Express         0
# 2                                 NaN      1026
# 3                                 NaN       633
# 4        btwn Cochrain & Pottinger St       450
#
#                                     formattedAddress  \
# 0                   [Kinwick Centre, Shelley St, 香港]
# 1  [Man Cheung St. (Hong Kong Station, Airport Ex...
# 2        [B/F, Pacific Place, 88 Queensway, 中西區, 香港]
# 3         [Shop 206, Shun Tak Centre, Hong Kong, 香港]
# 4  [92 Wellington St (btwn Cochrain & Pottinger S...
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 22.28200948348554...  22.282009  114.153296
# 1  [{'label': 'display', 'lat': 22.28504661513501...  22.285047  114.158380
# 2  [{'label': 'display', 'lat': 22.27792296623498...  22.277923  114.164712
# 3  [{'label': 'display', 'lat': 22.28779568111136...  22.287796  114.152997
# 4  [{'label': 'display', 'lat': 22.28292072899061...  22.282921  114.154651
#
#   neighborhood postalCode      state                        id
# 0          NaN        NaN        NaN  537dedb3498e9239c5267673
# 1          NaN        NaN        中西區  4ccfa2326449a09306f9c5cf
# 2          NaN        NaN        中西區  4bc541bf5935c9b6bcc9a5d2
# 3          NaN        NaN  Hong Kong  533fff61498e424c5874d29e
# 4          NaN        NaN        中西區  4f56e921e4b01d8a92a28b70

# %% [markdown]
# Finishing the dataframe what we need next step.

# %%
hk_df_new = hk_df.drop(['formattedAddress','labeledLatLngs','crossStreet','city','country','neighborhood','postalCode'],axis=1)
hk_df_new.head()
# Out:
#                      name                     categories  \
# 0    Marks & Spencer Food                   Gourmet Shop
# 1  Food Expression (現代煮意)                     Restaurant
# 2         Great Food Hall                    Supermarket
# 3    Marks & Spencer Food                    Supermarket
# 4    Mana! Fast Slow Food  Vegetarian / Vegan Restaurant
#
#                             address  cc  distance        lat         lng  \
# 0        Kinwick Centre, Shelley St  HK       623  22.282009  114.153296
# 1                    Man Cheung St.  HK         0  22.285047  114.158380
# 2  B/F, Pacific Place, 88 Queensway  HK      1026  22.277923  114.164712
# 3         Shop 206, Shun Tak Centre  HK       633  22.287796  114.152997
# 4                  92 Wellington St  HK       450  22.282921  114.154651
#
#        state                        id
# 0        NaN  537dedb3498e9239c5267673
# 1        中西區  4ccfa2326449a09306f9c5cf
# 2        中西區  4bc541bf5935c9b6bcc9a5d2
# 3  Hong Kong  533fff61498e424c5874d29e
# 4        中西區  4f56e921e4b01d8a92a28b70

# %% [markdown]
# #### Methodology
# In this project we will direct our efforts on **detecting areas that have low restaurant density**, particularly those with low number of Chinese restaurants,which is smilar restaurants. We will limit our analysis to area ~500m around center.
#
# In first step we have collected the required data: **location and type (category) of every restaurant within 600 from Central.** We have also identified Chinese restaurants (according to Foursquare categorization).
#
# Second step in our analysis will be **visualize the map** and exploration of 'restaurant density' to identify a few promising areas close to center with low number of restaurants in general and focus our attention on those areas.
#
# In third and final step we will focus on most promising areas and within those create clusters of locations that meet some basic requirements established in discussion with stakeholders: we will take into consideration locations with no more than two restaurants in radius of 30 meters, and we want locations without Italian restaurants in radius of 100 meters. We will present map of all such locations but also create clusters (using **k-means clustering**) of those locations to identify general zones / neighborhoods / addresses which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# ### Analysis
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's **count the number of restaurants** in area **within 600m**:

# %%
nearby_hk_df = hk_df_new[hk_df_new.distance<= 600  ]

# %%
nearby_hk_df.groupby("categories").distance.agg(['count','mean','max','min'])
# Out:
#                                count        mean  max  min
# categories
# Asian Restaurant                   1  328.000000  328  328
# Bar                                1  470.000000  470  470
# Café                               1  598.000000  598  598
# Chinese Restaurant                 2  390.500000  468  313
# Creperie                           1  359.000000  359  359
# Department Store                   1  426.000000  426  426
# Diner                              1  206.000000  206  206
# Grocery Store                      2  530.000000  596  464
# Juice Bar                          3  339.333333  575   80
# Korean Restaurant                  1  586.000000  586  586
# Market                             1  486.000000  486  486
# Restaurant                         2   32.500000   65    0
# Supermarket                        1  570.000000  570  570
# Thai Restaurant                    1  535.000000  535  535
# Vegetarian / Vegan Restaurant      1  450.000000  450  450
# Vietnamese Restaurant              1  346.000000  346  346
# Wine Shop                          1  462.000000  462  462

# %% [markdown]
# From the data,we can see there are **12 restaurants** including the Chinese restaurant which we regard as the similar restaurant to Cantonese restaurant.The similar restaurant such as Chinese Restaurant or undefined Restaurants we should pick them up and avoid them as possible.So we can pick the range between **~100m and ~200m** or **~500 and ~600m**.

# %% [markdown]
# #### visualize the nearby_hk_df

# %%
map_nearby_hk_df = folium.Map(location=[latitude, longitude], zoom_start=15)
hk_center = [latitude, longitude]

for lat, lng, label in zip(hk_df_new.lat, hk_df_new.lng, nearby_hk_df.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(map_nearby_hk_df)
folium.Marker(hk_center).add_to(map_nearby_hk_df)
folium.Circle(hk_center, radius=200, fill=False, color='white').add_to(map_nearby_hk_df)
folium.Circle(hk_center, radius=300, fill=False, color='white').add_to(map_nearby_hk_df)
folium.Circle(hk_center, radius=600, fill=False, color='white').add_to(map_nearby_hk_df)
folium.Circle(hk_center, radius=700, fill=False, color='white').add_to(map_nearby_hk_df)
# display map
map_nearby_hk_df
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Cluster

# %%
from sklearn.cluster import KMeans

kclusters = 3

hk_df_new_clustering = nearby_hk_df.drop(["name", "categories", "address","state","id","cc"], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(hk_df_new_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# array([2, 1, 0, 0, 0], dtype=int32)

# %%
hk_merged = nearby_hk_df.copy()

# add clustering labels
hk_merged["Cluster Labels"] = kmeans.labels_


print(hk_merged.shape)
hk_merged.head() # check the last columns!
# Out:
# (22, 10)
#                          name                     categories  \
# 1      Food Expression (現代煮意)                     Restaurant
# 4        Mana! Fast Slow Food  Vegetarian / Vegan Restaurant
# 5  Chiu Lung Fast Food (昭隆美食)             Chinese Restaurant
# 6                   nood food                      Juice Bar
# 8   Sun Hing Fast Food (新興美食)               Asian Restaurant
#
#                                              address  cc  distance        lat  \
# 1                                     Man Cheung St.  HK         0  22.285047
# 4                                   92 Wellington St  HK       450  22.282921
# 5                                 21-23 Chiu Lung St  HK       313  22.282659
# 6  2/F Asia Standard Tower,  59-65 Queen's Road C...  HK       363  22.283088
# 8                                        中環昭隆街9號B舖地下  HK       328  22.282521
#
#           lng state                        id  Cluster Labels
# 1  114.158380   中西區  4ccfa2326449a09306f9c5cf               2
# 4  114.154651   中西區  4f56e921e4b01d8a92a28b70               1
# 5  114.156753   中西區  4ca6a13cb0b8236a4b96a1e6               0
# 6  114.155551   中西區  522b194711d2d5f6266289c5               0
# 8  114.156717   NaN  4d58ca847e2237040d59a973               0

# %%
print(hk_merged.shape)
hk_merged.sort_values(["Cluster Labels"], inplace=True)

# %% [markdown]
# #### Finally, let's visualize the resulting clusters

# %%
# create map
import matplotlib.cm as cm
import matplotlib.colors as colors

map_clusters = folium.Map(location= hk_center, zoom_start=16)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, name, categories, cluster in zip(hk_merged['lat'], hk_merged['lng'], hk_merged['name'], hk_merged['categories'],hk_merged['Cluster Labels']):
    label = folium.Popup('{} - Cluster {}'.format(name, cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
folium.Circle(hk_center, radius=200, fill=False, color='white').add_to(map_clusters)
folium.Circle(hk_center, radius=300, fill=False, color='white').add_to(map_clusters)
folium.Circle(hk_center, radius=600, fill=False, color='white').add_to(map_clusters)
folium.Circle(hk_center, radius=700, fill=False, color='white').add_to(map_clusters)      
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Examine Clusters

# %% [markdown]
# #### Cluster 1

# %%
hk_merged.loc[hk_merged['Cluster Labels'] == 0, hk_merged.columns[[1] + list(range(5, hk_merged.shape[1]))]]
# Out:
#     categories        lat         lng state                        id  \
# 1   Restaurant  22.285047  114.158380   中西區  4ccfa2326449a09306f9c5cf
# 40  Restaurant  22.284725  114.157844   中西區  5976d56d002f4c4336fed1ba
# 20   Juice Bar  22.284978  114.159157   NaN  5ab4c8891987ec33c08ba3c2
#
#     Cluster Labels
# 1                0
# 40               0
# 20               0

# %% [markdown]
# #### Cluster 2

# %%
hk_merged.loc[hk_merged['Cluster Labels'] == 1, hk_merged.columns[[1] + list(range(5, hk_merged.shape[1]))]]
# Out:
#                        categories        lat         lng      state  \
# 45               Department Store  22.281440  114.156964        中西區
# 28                         Market  22.283528  114.153953        NaN
# 27                            Bar  22.283289  114.154229        NaN
# 25                      Wine Shop  22.280999  114.159417        NaN
# 22                      Juice Bar  22.280751  114.155257        NaN
# 16              Korean Restaurant  22.285231  114.152688        NaN
# 34                           Café  22.285315  114.152576  Hong Kong
# 29                  Grocery Store  22.281053  114.159719        NaN
# 13                Thai Restaurant  22.281165  114.155296        NaN
# 12             Chinese Restaurant  22.283723  114.154065        中西區
# 4   Vegetarian / Vegan Restaurant  22.282921  114.154651        中西區
# 21                  Grocery Store  22.279938  114.160165        NaN
# 32                    Supermarket  22.283807  114.153009        NaN
#
#                           id  Cluster Labels
# 45  4b0588ddf964a520a4dd22e3               1
# 28  5129df90e4b0fd966410da3b               1
# 27  4b0588cdf964a520b4da22e3               1
# 25  4c09e137009a0f47fe9ee8bf               1
# 22  560cb17f498ebf43db58949a               1
# 16  533a41d0498ef2793daea5ed               1
# 34  5a72b03f8ad62e6caa9f206f               1
# 29  55669c49498e2f10228b956a               1
# 13  4b0588d6f964a5207adc22e3               1
# 12  4e7c1ea3b8f75b2042a7c7e3               1
# 4   4f56e921e4b01d8a92a28b70               1
# 21  5afa5a42dec1d6002c7e8e3a               1
# 32  57cbd43f498e011eae709593               1

# %% [markdown]
# #### Cluster 3

# %%
hk_merged.loc[hk_merged['Cluster Labels'] == 2, hk_merged.columns[[1] + list(range(5, hk_merged.shape[1]))]]
# Out:
#     categories        lat         lng state                        id  \
# 1   Restaurant  22.285047  114.158380   中西區  4ccfa2326449a09306f9c5cf
# 42  Restaurant  22.284725  114.157844   中西區  5976d56d002f4c4336fed1ba
# 20   Juice Bar  22.284978  114.159157   NaN  5ab4c8891987ec33c08ba3c2
#
#     Cluster Labels
# 1                2
# 42               2
# 20               2

# %% [markdown]
# ### Results and Discussion

# %% [markdown]
# Our analysis shows that although there is a great number of restaurants in this area, there are pockets of low restaurant density fairly close to city center. Highest concentration of restaurants was detected south and south-west from Central, so we focused our attention to areas south-east and east. Another area was identified as potentially interesting (the north and north -east ), but our attention was focused on **south-east and east of the Cluster2 area** which offer a combination of popularity among tourists, closeness to Central, strong socio-economic dynamics and a number of pockets of low restaurant density.
#
#
# Those location candidates were then clustered to create zones of interest which contain greatest number of location candidates. Addresses of centers of those zones were also generated using reverse geocoding to be used as markers/starting points for more detailed local analysis based on other factors.
#
# Result of all this is Cluster2 area containing largest number of potential new restaurant locations based on number of and distance to existing venues - both restaurants in general and Chinese restaurants particularly.This, of course, does not imply that those zones are actually optimal locations for a new restaurant! Purpose of this analysis was to only provide info on areas close to Central but not crowded with existing restaurants(particularly Cantonese) - it is entirely possible that there is a very good reason for small number of restaurants in any of those areas, reasons which would make them unsuitable for a new restaurant regardless of lack of competition in the area.Recommended zones should therefore be considered only as a starting point for more detailed analysis which could eventually result in location which has not only no nearby competition but also other factors taken into account and all other relevant conditions met.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Purpose of this project was to identify Hong Kong areas close to center with low number of restaurants (particularly Cantonese restaurants) in order to aid stakeholders in narrowing down the search for optimal location for a new Cantonese restaurant.By calculating restaurant density distribution from Foursquare data we have first identified general boroughs that justify further analysis (what we mentioned above), and then generated extensive collection of locations which satisfy some basic requirements regarding existing nearby restaurants.Clustering of those locations was then performed in order to create major zones of interest (containing greatest number of potential locations) and addresses of those zone centers were created to be used as starting points for final exploration by stakeholders.
#
# Final decission on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location (proximity to park or water), levels of noise / proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
